# %% [markdown]
# # 0-0. Google Colab과 파이썬 노트북
#
# > **이 노트북의 목표**
# > 앞으로의 모든 실습은 **Google Colab**에 접속해서, `.ipynb` 확장자를 가진 **파이썬 노트북**을 실행하는 방식으로 진행됩니다.
# > 오늘은 **Colab을 먼저 켜고**, 그 위에서 노트북 사용법을 하나씩 직접 해 봅니다.
#
# ## 진행 순서
#
# | 순서 | 내용 |
# |:--|:--|
# | Part 1 | **Colab 접속하기** — 계정, 새 노트북, GPU 켜기 |
# | Part 2 | **노트북 다루기** — 셀, 커널, 실행 순서, Markdown |
# | Part 3 | **Colab 활용하기** — 파일, Google Drive |
# | Part 4 | 단축키 |
# | Part 5 | 주의사항 |
# | Part 6 | 정리 |
#
# ## 학습 목표
#
# 1. Colab에 접속해 새 노트북을 만들고 GPU 런타임으로 바꿀 수 있다.
# 2. 셀(cell)과 커널(kernel)의 개념을 이해하고, 실행 순서가 왜 중요한지 안다.
# 3. 코드 셀 / 텍스트 셀을 작성하고 실행할 수 있다.
# 4. 파이썬 스크립트(`.py`)와 노트북(`.ipynb`)의 차이를 설명할 수 있다.
# 5. Markdown 기본 문법으로 설명을 작성할 수 있다.
# 6. 외부 라이브러리를 설치하고, 파일을 업로드·다운로드하며, Google Drive를 마운트할 수 있다.
#
# <br>
#
# > 📌 **표기 규칙**
# > - 🖱️ : 마우스로 클릭해서 하는 작업
# > - ▶️ : 아래 코드 셀을 직접 실행해 보는 부분
# > - ✅ : 다음으로 넘어가기 전 확인할 체크포인트
# > - ⚠️ : 자주 하는 실수
#
# > ⚠️ 이 노트북은 **Colab에서 열어야** 모든 셀이 정상 동작합니다.
# > (`drive.mount`, `!nvidia-smi` 등은 Colab 전용입니다.)
#
# > 참고 자료: [AI 공부를 위한 기본 환경 셋팅 – 구글 Colab (유라클, 2025.03.07)](https://uracle.blog/2025/03/07/ai-%EA%B3%B5%EB%B6%80%EB%A5%BC-%EC%9C%84%ED%95%9C-%EA%B8%B0%EB%B3%B8-%ED%99%98%EA%B2%BD-%EC%85%8B%ED%8C%85-%EA%B5%AC%EA%B8%80-colab/)

# %% [markdown]
# ---
# # Part 1. Colab 접속하기
#
# ## 1-1. Colab이란?
#
# 정식 명칭은 **Colaboratory**. 구글이 제공하는 **클라우드 기반의 무료 파이썬 노트북 실행 환경**입니다.
# 내 컴퓨터에 파이썬을 설치하지 않아도, **웹 브라우저와 구글 계정만으로** 바로 시작할 수 있습니다.
#
# | 장점 | 설명 |
# |:--|:--|
# | **무료** | 구글 계정만 있으면 별도 비용 없이 사용 |
# | **클라우드 기반** | 파이썬·패키지 설치 등 로컬 환경 구축이 불필요 |
# | **GPU / TPU 지원** | 딥러닝처럼 연산이 많은 작업을 가속 (요금제에 따라 사용량 차등) |
# | **협업** | 구글 문서처럼 링크 공유 → 실시간 공동 작업 |
# | **Drive 연동** | 내 Google Drive의 파일을 바로 읽고 쓰기 |
#
# > 정리하면 **"설치 없이 바로 쓰는 노트북 + 무료 GPU"** 가 Colab을 쓰는 이유입니다.
#
# ## 1-2. 3단계로 시작하기
#
# 🖱️ **지금 바로 따라하세요.**
#
# 1. **접속** : https://colab.research.google.com 에 들어가 구글 계정으로 로그인
# 2. **새 노트북 만들기** : `파일(File)` → `새 노트(New notebook)`
# 3. **실습하기** : 코드 셀에 `print("Hello")` 를 쓰고 `Shift + Enter`
#
# 만든 노트북은 자동으로 내 Google Drive의 `Colab Notebooks` 폴더에 저장됩니다.
# 노트북 이름은 상단의 `Untitled0.ipynb` 를 클릭해서 바꿀 수 있습니다.
#
# ### ▶️ 실습 — 강의 자료를 내 드라이브로 가져오기
#
# 지금 보고 있는 이 노트북은 **강의용 GitHub 저장소**에 올라와 있습니다.
# GitHub에서 연 노트북은 **읽기 전용**이라 내가 실행한 결과가 저장되지 않습니다.
# 그래서 **가장 먼저 내 드라이브에 사본을 만들어 두고**, 그 사본으로 실습해야 합니다.
#
# **① GitHub에 있는 노트북 열기**
#
# 1. Colab에서 `파일(File)` → `노트 열기(Open notebook)`
# 2. 왼쪽 탭에서 **`GitHub`** 선택
# 3. 검색창에 저장소 주소 입력 → `Hyelim-Shin/AIdev` → `Enter`
# 4. (필요하면) 오른쪽 **`Branch`** 목록에서 강의 브랜치 선택
# 5. 파일 목록에서 `0-0.notebook_and_colab.ipynb` 클릭
#
# > 💡 더 빠른 방법 — GitHub 파일 주소에서 `github.com` 만 `colab.research.google.com/github` 로 바꿔 주소창에 붙여넣으면 바로 열립니다.
# > `https://github.com/...` → `https://colab.research.google.com/github/...`
#
# **② 내 드라이브에 사본 저장하기** ⭐
#
# 6. ⚠️ 화면 위쪽에 **`변경사항을 유지하려면 GitHub에 저장하세요`** 라는 안내가 뜹니다. 셀 실행은 되지만 **수정 사항이 저장되지 않습니다.**
# 7. `파일(File)` → **`드라이브에 사본 저장(Save a copy in Drive)`** 클릭
# 8. 새 탭에 `0-0.notebook_and_colab.ipynb의 사본` 이 열립니다 → **지금부터는 이 사본에서 실습**
# 9. 상단의 파일 이름을 클릭해 파일명 수정 가능
#
# ✅ **확인** — 사본은 내 Google Drive의 `Colab Notebooks` 폴더에 저장됩니다.
# 드라이브를 열어 파일이 실제로 있는지 확인해 보세요. 여기부터는 원본이 아니라 **내 파일**이므로 마음대로 고쳐도 됩니다.
#
# ⚠️ 원본(GitHub) 탭에서 계속 실습하다가 브라우저를 닫으면 **한 시간 작업이 통째로 날아갑니다.**
# 지금 열려 있는 탭이 `...의 사본` 이 맞는지 한 번 더 확인하세요.

# %% [markdown]
# ## 1-3. 런타임 — 내 코드를 실행해 주는 "빌려 쓰는 컴퓨터"
#
# **런타임(runtime)** 은 내 코드를 실제로 실행하는 **구글 서버의 컴퓨터 한 대**입니다.
# Colab을 쓴다는 것은, 내 노트북(laptop)이 아니라 **구글이 잠깐 빌려주는 컴퓨터를 브라우저로 원격 조종**하는 것입니다.
# 그래서 내 컴퓨터가 낡아도 Colab에서는 GPU를 쓸 수 있습니다.
#
# 여기서 **두 가지를 꼭 구분**해야 합니다. 이걸 헷갈리면 앞으로 계속 당황하게 됩니다.
#
# | | 실제로 어디에 있나 | 언제 사라지나 |
# |:--|:--|:--|
# | **노트북 파일** (내가 쓴 코드·텍스트) | 내 **Google Drive** | 내가 지우지 않는 한 안 사라짐 |
# | **런타임** (변수, 설치한 패키지, `/content`에 만든 파일) | **구글이 빌려준 컴퓨터**의 메모리·디스크 | 연결이 끊기면 **전부 사라짐** |
#
# 즉 코드(노트북 파일)는 멀쩡히 남고, **그때까지 실행해서 메모리에 쌓아 둔 변수와 결과만** 없어집니다.
# 없어졌으면 셀을 위에서부터 다시 실행하면 그만입니다.
#
# 🖱️ **GPU 켜기** (딥러닝 실습 때 필요)
#
# 1. 상단 메뉴 `런타임(Runtime)` → `런타임 유형 변경(Change runtime type)`
# 2. 하드웨어 가속기: **T4 GPU** 선택 → `저장`
# 3. 우측 상단 `연결(Connect)` 클릭 → 초록색 체크가 뜨면 연결 완료
#
# > ⚠️ 하드웨어 가속기를 바꾸면 **CPU만 있던 컴퓨터를 반납하고 GPU가 달린 다른 컴퓨터를 새로 배정**받습니다.
# > 그전에 만들어 둔 변수는 모두 없어지므로, **작업을 시작하기 전에 미리** 바꿔 두는 것이 좋습니다.
#
# ▶️ 아래 셀을 실행해서 GPU가 정말 붙었는지 확인합니다. (첫 실행이라 연결에 몇 초 걸립니다)

# %%
# 앞의 ! 는 "이건 파이썬이 아니라 리눅스 명령어야" 라는 뜻입니다.
# !nvidia-smi

# %% [markdown]
# 출력에서 확인할 것
#
# * `Tesla T4` 같은 **GPU 이름**
# * `15360MiB` 같은 **GPU 메모리 크기**
#
# 아무것도 안 나오거나 `command not found` 가 뜬다면 → 런타임이 아직 **CPU**입니다. 1-3의 1~2번을 다시 하세요.
# (당장 GPU가 필요한 실습은 아니므로, CPU 상태여도 오늘 진행에는 문제 없습니다.)
#
# ✅ **체크포인트 1** — Colab 노트북이 열렸고, 셀을 실행해서 출력을 볼 수 있나요?
# 여기까지 되면 이제 노트북 사용법을 배울 준비가 끝났습니다.

# %% [markdown]
# ---
# # Part 2. 노트북(.ipynb) 다루기
#
# ## 2-1. 지금 보고 있는 이 파일의 정체
#
# 파이썬 코드를 담는 파일은 크게 **`.py`** 와 **`.ipynb`** 두 가지입니다.
#
# **`.py` 스크립트**는 코드만 들어 있는 파일입니다. 파일 전체를 한 번에 실행하고, 결과는 터미널에 텍스트로 나옵니다.
#
# **노트북(Notebook)** 은 코드를 **여러 조각(셀)으로 나누어 한 조각씩 실행**하고, 그 결과를 **코드 바로 아래에** 붙여 두는 문서입니다.
# 정식 명칭은 **Jupyter Notebook**이며, 파일 확장자는 `.ipynb` (**I**nteractive **Py**thon **N**ote**b**ook)입니다.
#
# | | `.py` 스크립트 | `.ipynb` 노트북 |
# |:--|:--|:--|
# | 실행 단위 | 파일 전체 | **셀 하나씩** |
# | 결과 확인 | 터미널 출력 | 코드 **바로 아래**에 표시 |
# | 그래프·표 | 별도 창 / 파일 저장 | 문서 안에 **그대로** 삽입 |
# | 설명 작성 | 주석(`#`)만 | **Markdown 텍스트 셀** |
# | 적합한 일 | 완성된 프로그램, 자동화 | **탐색·실험·학습·발표** |
#
# 데이터 분석과 머신러닝의 **초반 탐색 단계**는 "한 번에 완성"되지 않습니다.
# 데이터를 조금 보고 → 그래프를 그려 보고 → 모델을 바꿔 보고 → 다시 확인하는 **반복 실험**이라서,
# 중간 결과를 바로 눈으로 확인할 수 있는 노트북이 편합니다. 이 수업의 실습을 노트북으로 하는 이유도 그것입니다.
#
# ### ⚠️ 노트북이 만능은 아닙니다
#
# 노트북은 **탐색·학습·발표에 맞는 도구**일 뿐, 모든 상황에 쓰는 것이 아닙니다. 약점이 분명합니다.
#
# * 셀을 아무 순서로나 실행할 수 있어서 **재현이 어렵습니다** (2-4에서 직접 확인합니다)
# * 파일 내부가 JSON이라 **버전 관리(diff)와 코드 리뷰가 불편**합니다
# * 테스트, 모듈 재사용, 자동 실행(스케줄링)에는 맞지 않습니다
#
# 그래서 실제로는 **탐색은 노트북으로 하되, 자리를 잡은 코드는 `.py` 모듈로 옮겨** 쓰는 경우가 많습니다.
# 학습 파이프라인이나 서비스 코드를 노트북 상태 그대로 운영하는 일은 드뭅니다.

# %% [markdown]
# ## 2-2. 코드 셀 실행하기
#
# 노트북은 **셀(cell)의 모음**입니다. 종류는 두 가지뿐입니다.
#
# * **코드 셀 (Code cell)** : 파이썬 코드를 작성하고 실행하는 칸
# * **텍스트 셀 (Text cell)** : Markdown 문법으로 설명을 쓰는 칸 (지금 읽고 있는 이 칸)
#
# 코드 셀을 실행하는 방법은 두 가지입니다.
#
# * 셀 왼쪽의 **▶ 실행 버튼** 클릭
# * **`Shift + Enter`** (실행 후 다음 셀로 이동)
#
# ▶️ 직접 해 보세요.

# %%
print("Hello, Colab!")

# %% [markdown]
# 노트북의 편리한 점 하나 더 — **셀의 마지막 줄에 있는 값은 `print` 없이도 출력**되며,
# 표나 그래프 같은 결과물은 **그림 그대로** 표시됩니다.

# %%
2 ** 10   # print 없이도 마지막 줄의 값은 화면에 나옵니다

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2 * np.pi, 100)
plt.plot(t, np.sin(t))
plt.title("sin(t)")
plt.show()   # 그래프가 이 셀 바로 아래에 그려집니다

# %% [markdown]
# ## 2-3. 커널(kernel) — 셀들은 기억을 공유합니다
#
# **커널**은 셀에 적힌 코드를 실제로 실행해 주는 **파이썬 프로세스**입니다. (Colab에서는 런타임이 곧 커널입니다.)
#
# 핵심은 **노트북의 모든 셀이 하나의 커널을 공유한다**는 점입니다.
# 그래서 위 셀에서 만든 변수를 아래 셀에서 그대로 쓸 수 있고,
# 반대로 **커널을 다시 시작하면 모든 변수가 한꺼번에 사라집니다.**
#
# ▶️ 아래 두 셀을 순서대로 실행해 보세요.

# %%
message = "Hello, Colab!"
print(message)

# %%
# 위 셀에서 만든 변수를 그대로 사용할 수 있습니다.
print(message.upper())
print("글자 수 :", len(message))

# %% [markdown]
# ## 2-4. ⚠️ 셀은 "쓴 순서"가 아니라 "실행한 순서"대로 기억합니다
#
# 셀 왼쪽의 `[1]`, `[2]` 숫자는 **실행 순서**입니다. 위에서 아래로 배치한 순서가 아닙니다.
# 중간 셀만 여러 번 고쳐 실행하면 변수 상태가 꼬여서, **코드는 맞는데 결과가 이상한** 상황이 생깁니다.
#
# ▶️ 아래 두 셀을 실행하고, **두 번째 셀만 여러 번 반복 실행**해 보세요.

# %%
x = 10
print("x =", x)

# %%
x = x + 5   # 이 셀을 여러 번 실행해 보세요. 실행할 때마다 값이 계속 커집니다!
print("x =", x)

# %% [markdown]
# 결과가 이상하면 **처음부터 깨끗하게** 돌려보는 것이 정답입니다.
#
# 🖱️ `런타임(Runtime)` → `런타임 다시 시작 및 모두 실행(Restart and run all)`
#
# 1-3에서 봤듯이 이건 **내 컴퓨터를 재부팅하는 게 아니라**, 실행 환경을 아무 변수도 없는 처음 상태로 되돌린 뒤
# 첫 셀부터 순서대로 다시 실행하는 것입니다. 코드는 그대로 있으니 겁내지 말고 자주 쓰세요.
#
# > 과제나 보고서를 제출하기 전에는 항상 이 방법으로 **처음부터 끝까지 한 번에** 실행해서
# > 오류 없이 돌아가는지 확인하세요. "제 컴퓨터에서는 됐는데요"의 절반은 여기서 걸러집니다.
#
# ✅ **체크포인트 2** — 셀을 여러 번 실행했을 때 `x`가 계속 커지는 이유를 설명할 수 있나요?

# %% [markdown]
# ## 2-5. 텍스트 셀과 Markdown
#
# 텍스트 셀은 **더블 클릭**하면 편집 모드가 되고, 다 쓰고 나서 `Shift + Enter`를 누르면 서식이 적용된 모습으로 바뀝니다.
# (Colab은 편집 중 오른쪽에 미리보기를 함께 보여 줍니다.)
#
# ### Markdown 기본 문법
#
# | 요소 | 문법 | 결과 |
# |:--|:--|:--|
# | 제목 | `# 제목1` `## 제목2` `### 제목3` | 크기가 다른 제목 |
# | 강조 | `*기울임*` `**굵게**` `***굵은 기울임***` | *기울임* **굵게** ***굵은 기울임*** |
# | 목록 | `* 항목` / `1. 항목` | 글머리표 · 번호 목록 |
# | 링크 | `[표시할 글](URL)` | [부산대학교](https://www.pusan.ac.kr) |
# | 이미지 | `![설명](이미지 URL)` | 이미지 삽입 |
# | 인용 | `> 인용 내용` | 들여쓴 인용문 |
# | 코드(한 줄) | `` `code` `` | `code` |
# | 코드 블록 | ```` ```python … ``` ```` | 문법 강조된 코드 상자 |
# | 표 | `\| A \| B \|` + `\|:--\|:--\|` | 지금 보고 있는 이 표 |
# | 수식 | `$y = wx + b$` | $y = wx + b$ |
#
# <br>
#
# > 💡 **연습** : 이 셀을 더블 클릭해서 위 표가 실제로 어떻게 쓰여 있는지 직접 확인해 보세요.
# > 코드만 있는 노트북보다 **설명이 함께 있는 노트북**이 훨씬 좋은 보고서가 됩니다.

# %% [markdown]
# ---
# # Part 3. Colab 활용하기

# %% [markdown]
# ## 3-1. 파일 업로드 / 다운로드
#
# 내 PC와 Colab 사이에서 파일을 직접 주고받는 방법입니다.
#
# ```python
# from google.colab import files
#
# uploaded = files.upload()      # 내 PC → Colab (파일 선택 창이 뜹니다)
# files.download('sample.txt')   # Colab → 내 PC
# ```
#
# ▶️ 아래 셀은 실제로 파일을 하나 만들어 본 뒤, 업로드/다운로드 코드를 참고용으로 남겨 둔 것입니다.

# %%
# 파일 하나 만들어 보기
with open("sample.txt", "w", encoding="utf-8") as f:
    f.write("노트북에서 만든 첫 파일입니다.\n")

print(open("sample.txt", encoding="utf-8").read())

# --- 아래는 Colab 전용. 필요할 때 주석을 풀어 쓰세요 ---
# from google.colab import files
# uploaded = files.upload()          # 내 PC → Colab
# files.download('sample.txt')       # Colab → 내 PC

# %% [markdown]
# ## 3-2. Google Drive 마운트
#
# ### 마운트(mount)란?
# 저장 장치를 운영체제의 파일 시스템에 **연결해서 쓸 수 있게 만드는 것**.
# (예: USB를 꽂으면 `E:` 드라이브로 보이는 것)
#
# ### 왜 필요한가?
# Colab의 저장 공간(`/content`)은 **일회용**입니다. 런타임이 끊기면 방금 만든 `sample.txt` 도 **사라집니다.**
# 데이터셋과 학습 결과를 **내 Google Drive에 저장**해 두어야 다음에 다시 쓸 수 있습니다.
#
# 🖱️ **방법 1 (버튼)** : 왼쪽 사이드바 📁 파일 아이콘 → 드라이브 마운트 버튼 클릭 → 생성된 셀 실행
#
# ▶️ **방법 2 (코드)** : 아래 셀 실행 → 팝업에서 계정 선택 → 권한 허용

# %%
from google.colab import drive

drive.mount('/content/drive')   # 성공하면: Mounted at /content/drive

# %% [markdown]
# ### ▶️ 실습 — 드라이브에 있는 텍스트 파일 읽어서 출력하기
#
# 마운트가 끝나면 내 드라이브가 아래 경로로 연결됩니다.
#
# ```
# /content/drive/MyDrive/
# ```
#
# 🖱️ **먼저 웹브라우저에서 내 Google Drive를 열고 직접 준비하세요.**
#
# 1. 내 드라이브에 `AIdev_practice` 폴더 만들기
# 2. 그 안에 텍스트 파일 하나 올리기 (예: `sample.txt`)
#
# ▶️ 이제 아래 셀로 **그 파일을 파이썬에서 열어 내용을 출력**해 봅니다.
# 경로는 `/content/drive/MyDrive/` 뒤에 폴더 이름과 파일 이름을 이어 붙이면 됩니다.
#
# > ⚠️ 한글이 들어간 파일은 `encoding="utf-8"` 을 붙여야 글자가 깨지지 않습니다.

# %%
# 내 드라이브에 올려 둔 파일의 경로 (폴더명·파일명은 본인 것에 맞게 수정하세요)
file_path = "/content/drive/MyDrive/AIdev_practice/sample.txt"

# 파일을 열어서 내용을 읽고 화면에 출력하기
with open(file_path, "r", encoding="utf-8") as f:
    content = f.read()

print(content)

# %% [markdown]
# ---
# # Part 4. 유용한 단축키
#
# ## 4-1. 실행 관련 (가장 많이 씀)
#
# | 단축키 | 기능 |
# |:--|:--|
# | `Shift + Enter` | 현재 셀 실행 후 **다음 셀로 이동** |
# | `Ctrl + Enter` | 현재 셀 실행 후 **제자리** |
# | `Alt + Enter` | 현재 셀 실행 후 **아래에 새 셀 추가** |
# | `Ctrl + F9` | 노트북의 **모든 셀 실행** |
# | `Ctrl + F8` | 현재 셀 **이전까지** 모두 실행 |

# %% [markdown]
# ## 4-2. 셀 편집 관련
#
# Colab은 `Ctrl + M` 을 누른 뒤 이어서 알파벳을 누르는 방식입니다.
# (일반 Jupyter Notebook에서는 `Esc` 를 눌러 명령 모드로 간 뒤 알파벳 하나만 누릅니다.)
#
# | Colab | Jupyter | 기능 |
# |:--|:--|:--|
# | `Ctrl + M, A` | `Esc` → `A` | 현재 셀 **위**에 새 셀 추가 (Above) |
# | `Ctrl + M, B` | `Esc` → `B` | 현재 셀 **아래**에 새 셀 추가 (Below) |
# | `Ctrl + M, D` | `Esc` → `D, D` | 현재 셀 **삭제** (Delete) |
# | `Ctrl + M, M` | `Esc` → `M` | 코드 셀 → **텍스트 셀**로 변경 (Markdown) |
# | `Ctrl + M, Y` | `Esc` → `Y` | 텍스트 셀 → **코드 셀**로 변경 |
# | `Ctrl + M, Z` | `Esc` → `Z` | 실행 취소 (셀 삭제 되돌리기) |

# %% [markdown]
# ## 4-3. 그 밖에
#
# | 단축키 | 기능 |
# |:--|:--|
# | `Ctrl + /` | 선택한 줄 **주석 처리 / 해제** |
# | `Ctrl + S` | 저장 (Colab은 자동 저장도 됩니다) |
# | `Ctrl + Shift + P` | 명령 팔레트 (모든 기능 검색) |
# | `Tab` | 자동 완성 |
# | `Shift + Tab` | 함수 설명 보기 |
#
# > 🖱️ 전체 목록은 `도구(Tools)` → `단축키(Keyboard shortcuts)` 에서 확인·변경할 수 있습니다.
#
# ▶️ 코드 안에서 도움말을 보는 방법도 알아 둡시다.

# %%
import numpy as np

# 함수 이름 뒤에 ? 를 붙이면 설명(docstring)이 나옵니다.
np.mean?

# help(np.mean) 도 같은 역할을 합니다.

# %% [markdown]
# ---
# # Part 5. ⚠️ Colab을 쓸 때 반드시 기억할 것
#
# | 상황 | 내용 |
# |:--|:--|
# | 유휴 시간 | 약 **90분** 동안 아무 조작이 없으면 런타임 종료 |
# | 최대 사용 | 연속 약 **12시간**이면 강제 종료 |
# | 종료되면 | `/content` 아래 파일, 설치한 패키지, **모든 변수가 삭제**됨 |
#
# 그 밖에 자주 겪는 문제들
#
# | 증상 | 원인 / 해결 |
# |:--|:--|
# | `NameError: name 'x' is not defined` | 그 변수를 만든 셀을 아직 실행하지 않음 → 위 셀부터 순서대로 실행 |
# | `FileNotFoundError` | 경로가 틀렸거나 런타임이 끊겨 파일이 사라짐 → `!ls` 로 확인 |
# | 결과가 이상함 | 실행 순서가 꼬임 → `런타임 다시 시작 및 모두 실행` |
# | `!cd` 했는데 폴더가 안 바뀜 | `%cd` 를 써야 함 |

# %% [markdown]
# ---
# # Part 6. 정리
#
# ## 치트시트
#
# ```python
#
# # --- 드라이브 마운트 ---
# from google.colab import drive
# drive.mount('/content/drive')
#
# # --- 파일 업로드 / 다운로드 ---
# from google.colab import files
# uploaded = files.upload()
# files.download('sample.txt')
# ```
#
# | 꼭 외울 단축키 | |
# |:--|:--|
# | `Shift + Enter` | 실행 후 다음 셀 |
# | `Ctrl + M, B` | 아래에 셀 추가 |
# | `Ctrl + M, D` | 셀 삭제 |
# | `Ctrl + /` | 주석 토글 |
#
# ## 자가 점검 체크리스트
#
# - [ ] GitHub의 강의 자료를 열어 **드라이브에 사본 저장**하고, 그 사본에서 실습했다
# - [ ] Colab에 접속해 새 노트북을 만들고 이름을 바꿔 봤다
# - [ ] 런타임 유형을 GPU로 바꾸고 `!nvidia-smi` 로 확인해 봤다
# - [ ] 셀의 실행 순서가 결과에 영향을 준다는 것을 이해했다
# - [ ] 코드 셀과 텍스트 셀을 추가·삭제·변환할 수 있다
# - [ ] `.py` 와 `.ipynb` 의 차이를 한 문장으로 설명할 수 있다
# - [ ] Markdown으로 제목·목록·표·코드 블록을 쓸 수 있다
# - [ ] Google Drive를 마운트하고 폴더 안의 파일을 읽어 봤다
#
#
# ## 참고자료
#
# * [Colab 공식 소개 노트북](https://colab.research.google.com/notebooks/intro.ipynb)
# * [Jupyter Notebook 공식 문서](https://docs.jupyter.org/en/latest/)
# * [Markdown 가이드 (한국어)](https://gist.github.com/ihoneymon/652be052a0727ad59601)
# * [AI 공부를 위한 기본 환경 셋팅 – 구글 Colab (유라클)](https://uracle.blog/2025/03/07/ai-%EA%B3%B5%EB%B6%80%EB%A5%BC-%EC%9C%84%ED%95%9C-%EA%B8%B0%EB%B3%B8-%ED%99%98%EA%B2%BD-%EC%85%8B%ED%8C%85-%EA%B5%AC%EA%B8%80-colab/)

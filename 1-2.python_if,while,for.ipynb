# %% [markdown]
# # Python Review

# %% [markdown]
# ## 1. if문

# %% [markdown]
# **비교 연산자**
#
# | 비교연산자 | 설명 |
# |:--|:--|
# | ```x < y``` | ```x```가 ```y```보다 작다. |
# | ```x > y``` | ```x```가 ```y```보다 크다. |
# | ```x == y``` | ```x```와 ```y```가 같다. |
# | ```x != y``` | ```x```와 ```y```가 같지 않다. |
# | ```x >= y``` | ```x```가 ```y```보다 크거나 같다. |
# | ```x <= y``` | ```x```가 ```y```보다 작거나 같다. |

# %%
x = 3
y = 2
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
## 만약 3000원 이상의 돈을 가지고 있으면 택시를 타고 가고, 그렇지 않으면 걸어가라.

money = int(input())
if money : ## 적절한 조건문을 넣어주세요
    print("택시를 타고 가라")
else:
    print("걸어가라")

# %% [markdown]
# **and, or, not**
#
# | 연산자 | 설명 |
# |:--|:--|
# | ```x or y``` | ```x```와 ```y``` 둘 중 하나만 참이어도 참이다. |
# | ```x and y``` | ```x```와 ```y```모두 참이어야 참이다. |
# | ```not x``` | ```x```가 거짓이면 참이다. |

# %%
## 돈이 3000원 이상 있거나 카드가 있다면 택시를 타고 가고, 그렇지 않으면 걸어가라.

money = 2000
card = True

if money : ## 적절한 조건문을 넣어주세요
    print("택시를 타고 가라")
else:
    print("걸어가라")

# %% [markdown]
# **in, not in**
#
# | ```(not) in``` | 설명 |
# |:--|:--|
# | ```x (not) in``` 리스트 | ```x```가 리스트에 존재한다(존재하지 않는다). |
# | ```x (not) in``` 튜플 | ```x```가 리스트에 존재한다(존재하지 않는다). |
# | ```x (not) in``` 문자열 | ```x```가 리스트에 존재한다(존재하지 않는다). |

# %%
1 in [1, 2, 3]

# %%
1 not in [1, 2, 3]

# %%
'a' in ('a', 'b', 'c')
# Out:
# True

# %%
'a' in 'apple'

# %%
## 주머니에 돈이 있으면 가만히 있고, 주머니에 돈이 없으면 카드를 꺼내라.

pocket = ['paper', 'cellphone', 'money']

# PUT YOUR CODE BELOW

# %% [markdown]
# ### ```elif```

# %%
## 주머니에 돈이 있으면 택시를 타고 가고, 주머니에 돈은 없지만 카드가 있으면 택시를 타고 가고, 돈도 없고 카드도 없으면 걸어가라.

pocket = ['paper', 'cellphone']
card = True

# PUT YOUR CODE BELOW

# %%
## 점수를 입력하면 학점을 출력하는 코드를 만들어보자
# 90점 이상: A, 75점 이상: B, 60점 이상: C, 40점 이상: D, 40점 미만: F

score = input()
# PUT YOUR CODE BELOW

# %% [markdown]
# ### 조건부 표현식

# %%
## 점수가 60점 이상이면 "합격", 미만이면 "불합격"

score = 85
if score >= 60:
    result = "합격"
else:
    result = "불합격"

print(result)

# %%
score = 85
result = "합격" if score >= 60 else "불합격"
print(result)

# %%
## 19세 이상이면 성인, 미만이면 미성년자
age = 20

status =

# %% [markdown]
# ### 반복문

# %% [markdown]
# #### While 문
#
# 조건문이 참인 동안 while 문에 속한 문장들을 반복해서 수행한다.

# %%
prompt = """
1. Add
2. Del
3. List
4. Quit

Enter number: """

# %%
number = 0
while number != 4:
    print(prompt)
    number = int(input())
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:
#
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number:

# %% [markdown]
# **while문 강제로 빠져나가기: ```break```**
#
# ![자판기 Logic](https://static.wikidocs.net/images/page/21/03_2_coffee.png)

# %%
## 자판기 
coffee = 10
while True:
    money = int(input("돈을 넣어 주세요: "))
    ## Put your code below

# %%
num = 1
while num <= 100:
    print(num)
    num = num + 1

# %% [markdown]
# **while문의 맨 처음으로 돌아가기: ```continue```**

# %%
## 1부터 10까지의 숫자 중에서 홀수만 출력하는 프로그램

a = 0
while a < 10:
    ## Input your code below
# Out:
#   Cell In[13], line 5
#     ## Input your code below
#                             ^
# SyntaxError: incomplete input

# %% [markdown]
# #### For 문
#
# ```python
# for 변수 in 리스트(또는 튜플, 문자열):
#     수행할_문장1
#     수행할_문장2
#     ...
# ```

# %%
family = ['mother', 'father', 'sister', 'dog']
for f in family:
    print(f)

# %%
for f in family:
    print(f, len(f))

# %%
## 숫자 n을 입력하면 구구단의 n단을 출력하는 코드를 만들어보자 (for문 사용)

n = int(input())
# PUT YOUR CODE BELOW

# %% [markdown]
# ### 연습문제

# %% [markdown]
# 1. 윤년 계산
#
# > 1. 서력 기원 연수가 4로 나누어 떨어지는 해는 윤년으로 한다. (1988년, 1992년, 1996년, 2004년, 2008년, 2012년, 2016년, 2020년, 2024년, 2028년, 2032년, 2036년, 2040년, 2044년 ...)
# > 2. 서력 기원 연수가 4, 100으로 나누어 떨어지는 해는 평년으로 한다. (1900년, 2100년, 2200년, 2300년, 2500년...)
# > 3. 서력 기원 연수가 4, 100, 400으로 나누어 떨어지는 해는 윤년으로 둔다. (2000년, 2400년...)
#
# **[Output]**
#
# * 평년일 경우: ```yyyy년은 평년입니다.```
# * 윤년일 경우: ```yyyy년은 윤년입니다.```

# %%
is_leap_year = None

year = int(input())

## Put your code below

# %% [markdown]
# 2. 고무공을 100 미터 높이에서 떨어뜨리는데, 이 공은 땅에 닿을 때마다 원래 높이의 3/5 만큼 튀어오릅니다. 공이 열 번 튈 동안, 그때마다 공의 높이를 계산합니다. (while문 사용)

# %%
h = 100
b = 3/5

## Put your code below

# %% [markdown]
# 3. 숫자 n을 입력하면 구구단의 n단을 출력하는 코드 (for문 사용)

# %%
n = int(input())
# PUT YOUR CODE BELOW

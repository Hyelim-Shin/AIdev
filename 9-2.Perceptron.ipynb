# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. 퍼셉트론(Perceptron)
#
# * 퍼셉트론: 초기 형태의 인공신경망으로 다수의 입력으로부터 하나의 결과를 내보내는 알고리즘

# %%
from IPython.display import Image
Image(url='https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.neuron.png', width=500)
# Out:
# <img src="https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.neuron.png" width="500"/>

# %% [markdown]
# * 신경 세포 뉴런은 가지돌기에서 신호를 받아들이고, 이 신호가 일정치 이상의 크기를 가지면 축삭돌기를 통해서 신호를 전달

# %%
from IPython.display import Image
Image(url='https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.perceptron.png', width=300)
# Out:
# <img src="https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.perceptron.png" width="300"/>

# %% [markdown]
# * $x$: 입력값
# * $W$: 가중치(weight)
# * $y$: 출력값
#
# 가중치의 값이 클수록 해당 입력 값이 중요하다는 것을 의미
#
# 입력값과 가중치의 곱의 전체 합이 입계치(threshold)를 넘으면 인공 뉴런은 출력 신호로서 1을 출력, 그렇지 않을 경우 0을 출력(계단 함수, step function)

# %%
from IPython.display import Image
Image(url='https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.step_function.png', width=500)
# Out:
# <img src="https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.step_function.png" width="500"/>

# %% [markdown]
# $$
# if \sum_i^n{W_i x_i} \geq \theta \rightarrow y=1
# $$
#
# $$
# if \sum_i^n{W_i x_i} < \theta \rightarrow y=0
# $$

# %%
from IPython.display import Image
Image(url='https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.perceptron2.png', width=300)
# Out:
# <img src="https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.perceptron2.png" width="300"/>

# %% [markdown]
# $$
# if \sum_i^n{W_i x_i} + b \geq 0 \rightarrow y=1
# $$
#
# $$
# if \sum_i^n{W_i x_i} + b < 0 \rightarrow y=0
# $$

# %% [markdown]
# ##### 활성화 함수 (Activation function)
#
# * 입력을 받아 수학적 변환을 수행하고 출력을 생성하는 함수
# * 예) 시그모이드 함수, 계단 함수
#
# 위 퍼셉트론의 활성화함수가 시그모이드 함수로 바뀌면 로지스틱 회귀와 같음

# %%
## 하이퍼볼릭탄젠트 (Hyperbolic Tangent function)
x = np.arange(-5.0, 5.0, 0.1) # -5.0부터 5.0까지 0.1 간격 생성
y = np.tanh(x)

plt.plot(x, y)
plt.plot([0,0],[1.0,-1.0], ':')
plt.axhline(y=0, color='orange', linestyle='--')
plt.title('Tanh Function')
plt.show()

# %%
def relu(x):
    return np.maximum(0, x)

x = np.arange(-5.0, 5.0, 0.1)
y = relu(x)

plt.plot(x, y)
plt.plot([0,0],[5.0,0.0], ':')
plt.title('Relu Function')
plt.show()

# %% [markdown]
# ## 2. 단층 퍼셉트론(Single-Layer Perceptron)

# %%
def AND_gate(x1, x2):
    w1=0.5
    w2=0.5
    b=-0.7
    result = x1*w1 + x2*w2 + b
    if result <= 0:
        return 0
    else:
        return 1

# %%
AND_gate(0, 0), AND_gate(0, 1), AND_gate(1, 0), AND_gate(1, 1)
# Out:
# (0, 0, 0, 1)

# %%
def NAND_gate(x1, x2):
    w1=-0.5
    w2=-0.5
    b=0.7
    result = x1*w1 + x2*w2 + b
    if result <= 0:
        return 0
    else:
        return 1

# %%
## 실습: OR 게이트 구현
def OR_gate(x1, x2):
    #####################################
    # 여기에 코드를 작성하세요.
    #####################################
    if result <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# ## 3. 다층 퍼셉트론(MultiLayer Perceptron, MLP)
#
# 입력층과 출력층 사이 은닉층(hidden layer)이 존재

# %%
Image(url='https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.mlp.png', width=500)

# %%
## 실습: XOR 게이트 구현
def XOR_gate(x1, x2):
    #####################################
    # 여기에 코드를 작성하세요.
    #####################################
    return y

# %%
Image(url='https://raw.githubusercontent.com/Hyelim-Shin/AIdev/master/Images/9-2.DNN.png', width=500)

# %% [markdown]
# * **심층 신경망(Deep Neural Network, DNN)**: 은닉층이 2개 이상인 신경망. 다층 퍼셉트론 외에도 여러 변형된 다양한 신경망들도 은닉층이 2개 이상이 되면 심층 신경망이라고 함
#
# * **딥 러닝(Deep learning)**: 심층 신경망을 학습시키는(=가중치를 기계가 스스로 찾아내도록 자동화시키는) 것
